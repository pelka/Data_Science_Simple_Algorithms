# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# Import libraries

# %%
import numpy as np
import pandas as pd
# Matplotlib for ploting data
import matplotlib.pyplot as plt
# Sklearn (split the dataset)
from sklearn.model_selection import train_test_split
# Sklearn (lineal regression model)
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Import dataset and split in testing and training set

# %%
dataset = pd.read_csv('../../../data/Salary_Data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3)

# %% [markdown]
# ## Build model

# %% [markdown]
# Create a simple lineal regression model with training set

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Evaluation of results

# %% [markdown]
# Predic with testing set

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Results of trained model

# %%
results = pd.DataFrame({
    'Data Test': y_test,
    'Prediction': np.around(y_pred, decimals=2) 
})

display(results)
# Out:
#    Data Test  Prediction
# 0    56957.0    63787.62
# 1   105582.0   111319.06
# 2   121872.0   125578.49
# 3    63218.0    62836.99
# 4    54445.0    56182.59
# 5    39891.0    46676.30
# 6    93940.0    82800.20
# 7    64445.0    56182.59
# 8    67938.0    72343.28
# 9    91738.0    90405.23

# %% [markdown]
# ## Data visualization

# %% [markdown]
# Plot training data

# %%
plt.style.use('fivethirtyeight')
plt.scatter(X_train, y_train)
plt.plot(X_train, model.predict(X_train), color="orangered")
plt.title("Training - Salary based on experience")
plt.xlabel("Years of experience")
plt.ylabel("Salary ($)")
plt.show()

# %% [markdown]
# Plot testing data

# %%
plt.style.use('fivethirtyeight')
plt.scatter(X_test, y_test)
plt.plot(X_train, model.predict(X_train), color="orangered")
plt.title("Testing - Salary based on experience")
plt.xlabel("Years of experience")
plt.ylabel("Salary ($)")
plt.show()
